# %%
def fib(n):
    assert n >= 2
    f0 = 0
    f1 = 1
    f2 = f1 + f0    
    i = 2
    while i < n:
        f0 = f1
        f1 = f2
        f2 = f1 + f0
        # print(i, f0, f1, f2)
        i += 1
    return f2

for n in range(2, 10):
    print(n, fib(n))
# Out:
# 2 1
# 3 2
# 4 3
# 5 5
# 6 8
# 7 13
# 8 21
# 9 34
