# %%
# !pip install yfinance
# !pip install pandas
# !pip install requests
# !pip install matplotlib

# %%
from price import YahooFinanceAdapter, save_csv

adapter = YahooFinanceAdapter("GOOG")
prices = adapter.fetch(("2025-01-01", "2025-02-01"))
save_csv("tmp.csv", prices)
# Out:
# Saved to tmp.csv

# %%
from price import read_csv, plot

prices = read_csv("tmp.csv", 1)
plot(prices)
